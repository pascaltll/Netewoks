# %%
def create_complete_graph(G, n):
    G.add_nodes_from(range(0, n))
    for i in range(0, n):
        for j in range(i+1, n):
            G.add_edge(i, j)

# %%
import networkx as nx
G = nx.read_gml('karate.gml', label=None)
nx.draw(G)

# %%
######first clas
import networkx as nx
G = nx.Graph()
G.add_nodes_from(range(10))
G.add_edge(1, 3)
nx.draw(G, with_labels=True)

# %%
import networkx as nx
G = nx.read_gml('EuroSiS Generale Pays.gexf', label=None)
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_60322/546537656.py in <module>
#       1 import networkx as nx
# ----> 2 G = nx.read_gml('EuroSiS Generale Pays.gexf', label=None)
#       3 nx.draw(G)
#
# ~/anaconda3/lib/python3.9/site-packages/networkx/utils/decorators.py in argmap_read_gml_1(path, label, destringizer)
#       1 from collections import defaultdict
#       2 from os.path import splitext
# ----> 3 from contextlib import contextmanager
#       4 from pathlib import Path
#       5 import warnings
#
# ~/anaconda3/lib/python3.9/site-packages/networkx/utils/decorators.py in _open_file(path)
#     186             return path, lambda: None
#     187
# --> 188         fobj = _dispatch_dict[ext](path, mode=mode)
#     189         return fobj, lambda: fobj.close()
#     190
#
# FileNotFoundError: [Errno 2] No such file or directory: 'EuroSiS Generale Pays.gexf'
